# %% [markdown]
# #  **Project Title: Forecasting System - Project Demand of Products at a Retail Outlet Based on Historical Data(Only data pre-processing done)**

# %% [markdown]
# **1.Load the data into the working environment**

# %% [markdown]
# In section we will import needed python libraries and load dataset into the google collab.

# %%
#import needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
#read the dataset
df = pd.read_csv("Superstore.csv")
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-08-11  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-08-12  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-08-13   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  2016-08-14  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  2016-08-15  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# **2.Do the data pre-processing**

# %% [markdown]
# See the head and tail of dataset

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-08-11  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-08-12  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-08-13   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  2016-08-14  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  2016-08-15  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  2017-04-05  05-09-2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# See the shape and columns of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#to see the description of dataset
df.describe(include='all')
# Out:
#              Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# count   9994.000000            9994        9994        9994            9994
# unique          NaN            5009        2232        1334               4
# top             NaN  CA-2017-100111  2017-02-12  12/16/2015  Standard Class
# freq            NaN              14          35          35            5968
# mean    4997.500000             NaN         NaN         NaN             NaN
# std     2885.163629             NaN         NaN         NaN             NaN
# min        1.000000             NaN         NaN         NaN             NaN
# 25%     2499.250000             NaN         NaN         NaN             NaN
# 50%     4997.500000             NaN         NaN         NaN             NaN
# 75%     7495.750000             NaN         NaN         NaN             NaN
# max     9994.000000             NaN         NaN         NaN             NaN
#
# ...

# %%
#drop the non-informative column
df.drop('Row ID',axis=1)
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  2016-08-11  11-11-2016    Second Class    CG-12520
# 1     CA-2016-152156  2016-08-12  11-11-2016    Second Class    CG-12520
# 2     CA-2016-138688  2016-08-13   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  2016-08-14  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  2016-08-15  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03-03-2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class    DB-13060
# 9993  CA-2017-119914  2017-04-05  05-09-2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
#check for missing values
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#check the different types of the product categories include
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
#Now we create a dataframe which includes only data related to furniture sales. 
furniture = df.loc[df['Category'] == 'Furniture']
furniture.head()
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156  2016-08-11  11-11-2016    Second Class
# 1        2  CA-2016-152156  2016-08-12  11-11-2016    Second Class
# 3        4  US-2015-108966  2016-08-14  10/18/2015  Standard Class
# 5        6  CA-2014-115812  2016-08-16   6/14/2014  Standard Class
# 10      11  CA-2014-115812  2016-08-21   6/14/2014  Standard Class
#
#    Customer ID    Customer Name   Segment        Country             City  \
# 0     CG-12520      Claire Gute  Consumer  United States        Henderson
# 1     CG-12520      Claire Gute  Consumer  United States        Henderson
# 3     SO-20335   Sean O'Donnell  Consumer  United States  Fort Lauderdale
# 5     BH-11710  Brosina Hoffman  Consumer  United States      Los Angeles
# 10    BH-11710  Brosina Hoffman  Consumer  United States      Los Angeles
#
#     ... Postal Code  Region       Product ID   Category Sub-Category  \
# ...

# %%
#To understand the first and last date of orders for the category furniture
furniture['Order Date'].min(), furniture['Order Date'].max()
# Out:
# ('1/13/2014', '9/30/2016')

# %%
#Data pre-processing by removing unnecessary columns from the furniture dataframe
cols = ['Row ID','Order ID','Ship Date','Ship Mode','Customer ID','Customer Name','Segment','Country','City','State','Postal Code','Region','Product ID','Category','Sub-Category','Product Name','Quantity','Discount','Profit']
furniture.drop(cols,axis=1,inplace=True)
furniture.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     Order Date      Sales
# 0   2016-08-11   261.9600
# 1   2016-08-12   731.9400
# 3   2016-08-14   957.5775
# 5   2016-08-16    48.8600
# 10  2016-08-21  1706.1840

# %%
#Sorting furniture datframe according to order date
furniture = furniture.sort_values('Order Date')
furniture
# Out:
#      Order Date    Sales
# 4938  1/13/2014  333.999
# 2978  1/13/2014  545.940
# 4857  1/13/2015   77.600
# 4858  1/13/2015  464.850
# 6621  1/13/2017  212.940
# ...         ...      ...
# 4473  9/29/2017  344.220
# 5791  9/29/2017   72.784
# 5793  9/29/2017   51.750
# 3283  9/30/2014   15.240
# 6945  9/30/2016  523.920
#
# [2121 rows x 2 columns]

# %% [markdown]
# Indexing of dataset

# %%
#To find how much total furniture sales occurred on each date
furniture = furniture.groupby('Order Date')['Sales'].sum().reset_index()

# %%
#set the Order date column as the index column
furniture['Order Date']=furniture['Order Date'].apply(lambda x: pd.to_datetime(x)) #to convert dd-mm-yyyy to yyyy-mm-dd format
furniture = furniture.set_index('Order Date')
furniture
# Out:
#                Sales
# Order Date
# 2014-01-13   879.939
# 2015-01-13   542.450
# 2017-01-13   212.940
# 2014-01-14    61.960
# 2016-01-14   315.776
# ...              ...
# 2017-09-28    42.016
# 2014-09-29  2948.788
# 2017-09-29   553.688
# 2014-09-30    15.240
# 2016-09-30   523.920
#
# [1046 rows x 1 columns]

# %%
#To see the  frequency in the dataframe
furniture.index
# Out:
# DatetimeIndex(['2014-01-13', '2015-01-13', '2017-01-13', '2014-01-14',
#                '2016-01-14', '2017-01-14', '2016-01-15', '2017-01-16',
#                '2014-01-19', '2015-01-19',
#                ...
#                '2017-09-26', '2014-09-27', '2015-09-27', '2016-09-27',
#                '2014-09-28', '2017-09-28', '2014-09-29', '2017-09-29',
#                '2014-09-30', '2016-09-30'],
#               dtype='datetime64[ns]', name='Order Date', length=1046, freq=None)

# %%
#Now let's resample the data into means of monthly sales of furniture and save this into a new variable called Order date
y_furniture = furniture['Sales'].resample('M').mean()
y_furniture
# Out:
# Order Date
# 2014-01-31    647.169077
# 2014-02-28    130.348333
# 2014-03-31    884.225750
# 2014-04-30    513.372154
# 2014-05-31    356.824462
#                  ...
# 2019-07-31    470.904400
# 2019-08-31    122.143000
# 2019-09-30    413.765000
# 2019-10-31    602.519200
# 2019-11-30    532.362000
# Freq: M, Name: Sales, Length: 71, dtype: float64

# %% [markdown]
# **3.Data visualization**

# %% [markdown]
# The sales data of furniture is plotted below

# %%
furniture.plot(figsize=(20,5))

# %% [markdown]
# The mean sales data of furniture is plotted below

# %%
y_furniture.plot(figsize=(10,5))
plt.title("Furniture supplies sales")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')
